# %% [markdown]
# ### Pattern replacement using REGEX

# %% [markdown]
# This notebook has been created with the sole purpose of correcting the spelling mistakes that can be found in the attacks dataframe. The reason to create  this additional notebook is mainly practical, as there a lot of pattern to replace, and I have not been able to find of way of optimazing the process

# %%
import pandas as pd
import re
import collections

# %%
data = pd.read_csv("data\data.csv")

# %%
def counts(column):
    '''
    This function returns the value_counts() result of a column as a dictionary sorted by key in ascending order.
    Easier to examine.
    Args: the column of interest in the format of df.column or df["columnd"]
    '''
    s = (column.value_counts())
    dictionary =  s.to_dict()
    return collections.OrderedDict(sorted(dictionary.items()))

# %% [markdown]
# ### Country

# %%
data.Country = data.Country.replace(to_replace = "CEYLON" , value = "SRI LANKA" )

# %%
data.Country = data.Country.replace(to_replace = r"\?$", value = "", regex = True)

# %%
data.Country = data.Country.replace(to_replace = 'MAARTIN', value = 'MARTIN', regex = True)

# %%
data.Country = data.Country.replace(to_replace = r'(\w* \/ .*)', value = 'UNKNOWN', regex = True)

# %%
data.Country = data.Country.replace(to_replace = 'RED UNKNOWN', value = 'UNKNOWN', regex = True)

# %%
data.Country = data.Country.replace(to_replace = 'SOLOMON UNKNOWN', value = 'SOLOMON ISLANDS', regex = True)

# %% [markdown]
# ### Time

# %%
data.Time = data.Time.replace(to_replace = r'(s\--\s\w{2}\w\w{2})', value ='UNKNOWN', regex = True )

# %%
data.Time = data.Time.replace(to_replace = 'Afternoon', value ='18h30', regex = True )

# %%
data.Time = data.Time.replace(to_replace = 'Dusk', value ='07h30', regex = True )

# %%
data.Time = data.Time.replace(to_replace = 'Early afternoon', value ='18h00', regex = True )

# %%
data.Time = data.Time.replace(to_replace = 'Evening', value ='20h00', regex = True )

# %%
data.Time = data.Time.replace(to_replace = 'Late afternoon', value ='19h30', regex = True )

# %%
data.Time = data.Time.replace(to_replace = 'Midday', value ='12h00', regex=True )

# %%
data.Time = data.Time.replace(to_replace = 'Midnight', value ='00h00', regex = True )

# %%
data.Time = data.Time.replace(to_replace = 'Morning', value ='08h30', regex = True )

# %%
data.Time = data.Time.replace(to_replace = 'Night', value ='21h30', regex = True )

# %%
data.Time = data.Time.replace(to_replace = r'(\/\w*)', value ='', regex = True )

# %%
data.Time = data.Time.replace(to_replace = '13h345', value ='13h45', regex = True )

# %%
data.Time = data.Time.replace(to_replace = '15h00j', value ='15h00', regex = True )

# %%
data.Time = data.Time.replace(to_replace = '0830', value ='08h30', regex = True )

# %%
data.Time = data.Time.replace(to_replace = '11h115', value ='11h15', regex = True )

# %%
data.Time = data.Time.replace(to_replace = '06j00', value ='06h00', regex = True )

# %%
data.Time = data.Time.replace(to_replace = r'(\<*)', value ='', regex = True )

# %%
data.Time = data.Time.replace(to_replace = r'(\>*)', value ='', regex = True )

# %%
data.Time = data.Time.replace(to_replace = r'h', value =':', regex = True )

# %%
data.Time = data.Time.replace(to_replace = 'fall', value ='', regex = True )

# %%
counts(data.Time)
# Out:
# OrderedDict([(' ', 4),
#              ('  ', 2),
#              ('   ', 1),
#              (' 14:00', 2),
#              ('"20:00"', 1),
#              ('"21:30"', 1),
#              ('"After dark"', 4),
#              ('"After lunc:"', 2),
#              ('"Early evening"', 16),
#              ('"Just before 11:00"', 4),
#              ('"s:ortly before dusk"', 7),
#              ('--', 6),
#              ('00:00', 13),
#              ('00:30', 1),
#              ('01:00', 18),
#              ('01:30', 3),
#              ('01:32', 3),
#              ('01:50', 9),
#              ('02:00', 19),
#              ('02:30', 2),
#              ('02:45', 1),
#              ('03:00', 8),
#              ('03:30', 3),
#              ('03:45 - 04:00', 3),
#              ('04:00', 11),
#              ('0500', 1),
#              ('05:00', 17),
#              ('05:30', 9),
#              ('05:40', 4),
#              ('05:45', 3),
#              ('05:50', 1),
#              ('06:00', 40),
#              ('06:00 -- 07:00', 7),
#              ('06:10', 3),
#              ('06:15', 3),
#              ('06:30', 18),
#              ('06:45', 10),
#              ('06:47', 4),
#              ('06:50', 1),
#              ('07:00', 35),
#              ('07:00 - 08:00', 1),
#              ('07:05', 2),
#              ('07:08', 1),
#              ('07:10', 1),
#              ('07:15', 7),
#              ('07:19', 3),
#              ('07:20', 2),
#              ('07:30', 85),
#              ('07:32', 1),
#              ('07:40', 5),
#              ('07:45', 10),
#              ('07:50', 2),
#              ('07:56', 1),
#              ('08:00', 62),
#              ('08:00  09:30', 2),
#              ('08:05', 3),
#              ('08:10', 8),
#              ('08:15', 12),
#              ('08:20', 2),
#              ('08:30', 406),
#              ('08:30 ', 1),
#              ('08:35', 1),
#              ('08:40', 1),
#              ('08:45', 26),
#              ('08:50', 3),
#              ('08:55', 1),
#              ('08:57', 2),
#              ('08:58', 2),
#              ('09:00', 102),
#              ('09:00 - 09:30', 6),
#              ('09:00 -10:00', 1),
#              ('09:05', 1),
#              ('09:11', 2),
#              ('09:15', 17),
#              ('09:20', 3),
#              ('09:30', 64),
#              ('09:30 ', 4),
#              ('09:30  10:00', 2),
#              ('09:30  15:30', 1),
#              ('09:35', 2),
#              ('09:40', 7),
#              ('09:45', 18),
#              ('09:50', 5),
#              ('09:55', 2),
#              ('09:57', 2),
#              ('10:00', 131),
#              ('10:00  11:00', 3),
#              ('10:00 -- 11:00', 1),
#              ('10:00 or 14:00', 3),
#              ('10:07', 2),
#              ('10:10', 2),
#              ('10:15', 15),
#              ('10:16', 1),
#              ('10:20', 20),
#              ('10:22', 3),
#              ('10:25', 6),
#              ('10:27', 1),
#              ('10:28', 1),
#              ('10:30', 81),
#              ('10:30 or 13:30', 5),
#              ('10:35', 6),
#              ('10:40', 7),
#              ('10:43', 1),
#              ('10:44', 1),
#              ('10:45', 18),
#              ('10:45-11:15', 1),
#              ('10:50', 3),
#              ('10:55', 17),
#              ('11:00', 240),
#              ('11:00  11:30', 1),
#              ('11:01 -time of s:ip sinking', 2),
#              ('11:05', 4),
#              ('11:06', 5),
#              ('11:10', 14),
#              ('11:15', 27),
#              ('11:20', 6),
#              ('11:25', 1),
#              ('11:30', 119),
#              ('11:30 ', 1),
#              ('11:40', 4),
#              ('11:41', 1),
#              ('11:45', 17),
#              ('11:48', 1),
#              ('11:50', 5),
#              ('11:51', 3),
#              ('11:53', 1),
#              ('11:55', 4),
#              ('11:56', 1),
#              ('11:57', 1),
#              ('11:58', 1),
#              ('12:00', 273),
#              ('12:00 to 14:00', 4),
#              ('12:00.', 4),
#              ('12:02', 1),
#              ('12:05', 5),
#              ('12:10', 3),
#              ('12:15', 26),
#              ('12:20', 7),
#              ('12:25', 2),
#              ('12:30', 63),
#              ('12:33', 4),
#              ('12:34', 1),
#              ('12:35', 1),
#              ('12:38', 2),
#              ('12:39', 1),
#              ('12:40', 7),
#              ('12:45', 25),
#              ('12:45  13:45', 2),
#              ('12:46', 1),
#              ('12:48', 2),
#              ('12:50', 4),
#              ('12:54', 2),
#              ('12:55', 1),
#              ('1300', 1),
#              ('13:00', 167),
#              ('13:05', 2),
#              ('13:06', 1),
#              ('13:10', 2),
#              ('13:14', 1),
#              ('13:15', 15),
#              ('13:19', 1),
#              ('13:20', 19),
#              ('13:23', 1),
#              ('13:24', 1),
#              ('13:25', 7),
#              ('13:26', 2),
#              ('13:30', 86),
#              ('13:35', 3),
#              ('13:37', 1),
#              ('13:40', 9),
#              ('13:42', 1),
#              ('13:45', 22),
#              ('13:50', 4),
#              ('13:51', 1),
#              ('13:53', 1),
#              ('13:55', 4),
#              ('14:00', 188),
#              ('14:00  -15:00', 1),
#              ('14:00 - 15:00', 1),
#              ('14:10', 17),
#              ('14:15', 9),
#              ('14:16', 5),
#              ('14:20', 8),
#              ('14:21', 2),
#              ('14:25', 5),
#              ('14:30', 146),
#              ('14:30  15:30', 1),
#              ('14:34', 1),
#              ('14:35', 9),
#              ('14:37', 1),
#              ('14:40', 12),
#              ('14:45', 36),
#              ('14:50', 8),
#              ('14:55', 8),
#              ('1500', 3),
#              ('15:00', 247),
#              ('15:00 or 15:45', 1),
#              ('15:01', 2),
#              ('15:05', 1),
#              ('15:06', 1),
#              ('15:15', 34),
#              ('15:19', 1),
#              ('15:20', 17),
#              ('15:25', 1),
#              ('15:30', 170),
#              ('15:35', 7),
#              ('15:40', 7),
#              ('15:44', 1),
#              ('15:45', 25),
#              ('15:49', 2),
#              ('15:50', 10),
#              ('15:52', 1),
#              ('15:53', 1),
#              ('15:55', 2),
#              ('15:56', 1),
#              ('15j45', 1),
#              ('1600', 2),
#              ('16:00', 203),
#              ('16:05', 7),
#              ('16:10', 7),
#              ('16:12', 2),
#              ('16:14', 1),
#              ('16:15', 26),
#              ('16:18', 4),
#              ('16:20', 15),
#              ('16:23', 1),
#              ('16:25', 5),
#              ('16:30', 157),
#              ('16:30 or 18:00', 2),
#              ('16:35', 3),
#              ('16:40', 15),
#              ('16:45', 28),
#              ('16:50', 5),
#              ('16:55', 1),
#              ('17:00', 133),
#              ('17:00 Sunset', 1),
#              ('17:00 or 17:40', 1),
#              ('17:00-18:00', 1),
#              ('17:01', 1),
#              ('17:10', 11),
#              ('17:11', 1),
#              ('17:15', 40),
#              ('17:17', 2),
#              ('17:20', 8),
#              ('17:30', 146),
#              ('17:34', 1),
#              ('17:35', 2),
#              ('17:40', 1),
#              ('17:42', 1),
#              ('17:45', 16),
#              ('17:46', 1),
#              ('17:50', 9),
#              ('17:51', 1),
#              ('17:55', 3),
#              ('17:58', 1),
#              ('18:00', 179),
#              ('18:05', 4),
#              ('18:10', 17),
#              ('18:12', 3),
#              ('18:15', 7),
#              ('18:15 to 21:30', 5),
#              ('18:15-18:30', 2),
#              ('18:20', 2),
#              ('18:25', 1),
#              ('18:30', 587),
#              ('18:30 (Sunset)', 2),
#              ('18:30?', 1),
#              ('18:40', 4),
#              ('18:45', 14),
#              ('18:50', 5),
#              ('19:00', 41),
#              ('19:00  20:00', 1),
#              ('19:00, 07:30', 1),
#              ('19:00-20:00', 8),
#              ('19:05', 3),
#              ('19:10', 3),
#              ('19:15', 6),
#              ('19:20', 3),
#              ('19:28', 1),
#              ('19:30', 114),
#              ('19:35', 3),
#              ('19:45', 6),
#              ('19:55', 3),
#              ('2 :ours after Opperman', 1),
#              ('2 :rs before sunset', 2),
#              ('20:00', 109),
#              ('20:15', 7),
#              ('20:30', 18),
#              ('20:45 (Sunset)', 2),
#              ('21:00', 8),
#              ('21:30', 237),
#              ('21:50', 1),
#              ('22:00', 6),
#              ('22:30', 1),
#              ('23:00', 13),
#              ('23:30', 4),
#              ('30 minutes after 1992.07.08.a', 1),
#              ('8:04 pm', 1),
#              ('9:00', 1),
#              ('A.M.', 35),
#              ('AM', 2),
#              ('After 04:00', 3),
#              ('After 07:30', 2),
#              ('After dusk', 2),
#              ('After midnig:t', 1),
#              ('After noon', 6),
#              ('Before 07:00', 2),
#              ('Before 10:30', 12),
#              ('Before daybreak', 5),
#              ('Between 05:00 and 08:00', 2),
#              ('Between 06:00 & 07:20', 1),
#              ('Between 11:00 & 12:00', 5),
#              ('Dark', 3),
#              ('Dawn', 2),
#              ('Daybreak', 1),
#              ('Daytime', 2),
#              ('Early 08:30', 1),
#              ('Early morning', 27),
#              ('FATAL  (Wire netting installed at local beac:es after t:is incident.)',
#               18),
#              ('Just after 12:00', 3),
#              ('Just before dawn', 2),
#              ('Just before noon', 3),
#              ('Just before sundown', 2),
#              ('Late 18:30', 2),
#              ('Late afternon', 7),
#              ('Late morning', 1),
#              ('Late nig:t', 2),
#              ('Lunc:time', 1),
#              ('Mid afternoon', 2),
#              ('Mid morning', 3),
#              ('Mid-morning', 3),
#              ('Noon', 1),
#              ('P.M.', 36),
#              ('Possibly same incident as 2000.08.21', 9),
#              ('Prior to 10:37', 1),
#              ('S:ip aban-doned at 03:10', 3),
#              ('S:ortly after midnig:t', 1),
#              ('S:ortly before 12:00', 2),
#              ('S:ortly before 13:00', 3),
#              ('Sometime between 06:00 & 08:oo', 4),
#              ('Sunset', 4),
#              ('X', 1),
#              ('dusk', 1),
#              ('nig:t', 1),
#              ('\xa0 ', 1)])

# %% [markdown]
# ### Type

# %%
data.Type = data.Type.replace(to_replace = 'Boating', value = 'Boat')

# %%
data.Type = data.Type.replace(to_replace = 'Boatomg', value = 'Boat')

# %%
data.Type = data.Type.replace(to_replace = 'Questionable', value = 'Unknown')

# %%
data.Type.value_counts()
# Out:
# Unprovoked      4594
# Provoked         574
# Invalid          547
# Boat             341
# Sea Disaster     239
# Unknown            6
# Name: Type, dtype: int64

# %% [markdown]
# ### Activity

# %%
data.Activity= data.Activity.replace(to_replace = r'\s(\w*\s)*\w*', value ='', regex = True )

# %%
data.Activity= data.Activity.replace(to_replace = r'(\-\w*)+', value ='', regex = True )

# %%
data.Activity= data.Activity.replace(to_replace = 'Surf', value ='Surfing', regex = True )

# %%
data.Activity= data.Activity.replace(to_replace = 'Body', value ='Surfing', regex = True )

# %%
data.Activity= data.Activity.replace(to_replace = 'Surfinging', value ='Surfing', regex = True )

# %%
data.Activity= data.Activity.replace(to_replace = 'Surfingsitting', value ='Surfing', regex = True )

# %%
data.Activity= data.Activity.replace(to_replace = 'Windsurfing', value ='Surfing', regex = True )

# %%
data.Activity= data.Activity.replace(to_replace = 'Paddling', value ='Surfing', regex = True )

# %%
data.Activity= data.Activity.replace(to_replace = 'Paddle', value ='Surfing', regex = True )

# %%
data.Activity= data.Activity.replace(to_replace = r'Kayak', value ='Kayaking', regex = True )

# %%
data.Activity= data.Activity.replace(to_replace = 'Kayakinging', value ='Kayaking', regex = True )

# %%
data.Activity= data.Activity.replace(to_replace = 'Freedom', value ='Swimming', regex = True )

# %%
data.Activity= data.Activity.replace(to_replace = 'Scuba', value ='Diving', regex = True )

# %%
data.Activity= data.Activity.replace(to_replace = 'Dived', value ='Diving', regex = True )

# %%
data.Activity= data.Activity.replace(to_replace = 'Divingdiving', value ='Diving', regex = True )

# %%
data.Activity= data.Activity.replace(to_replace = 'Divingbut', value ='Diving', regex = True )

# %%
data.Activity= data.Activity.replace(to_replace = 'Pearl', value ='Diving', regex = True )

# %%
data.Activity= data.Activity.replace(to_replace = 'Floating', value ='Bathing', regex = True )

# %%
data.Activity= data.Activity.replace(to_replace = 'boat', value ='Boating', regex = True )

# %%
data.Activity= data.Activity.replace(to_replace = 'Boat', value ='Boating', regex = True )

# %%
data.Activity= data.Activity.replace(to_replace = 'Boatinging', value ='Boating', regex = True )

# %%
data.Activity= data.Activity.replace(to_replace = 'Sailing', value ='Boating', regex = True )

# %%
counts(data.Activity)
# Out:
# OrderedDict([('', 3),
#              ('"Boating"', 1),
#              ('"Climbing"', 1),
#              ('"Crossing"', 1),
#              ('"Flying"', 2),
#              ('"Riding"', 1),
#              ('"Swimming"', 1),
#              ('.', 3),
#              ("12's'", 1),
#              ('13&', 1),
#              ('14&', 1),
#              ('1446,..,&.(5)/12/1909', 1),
#              ("16',,", 1),
#              ('17', 1),
#              ('2', 1),
#              ('2(Jeppsen)&(13).,.’t', 1),
#              ('25', 1),
#              ('3', 1),
#              ('3&', 1),
#              ('3,909', 1),
#              ('3.3.&(wearing)', 1),
#              ('4', 1),
#              ("40'", 1),
#              ('43&', 1),
#              ("63''", 1),
#              ('90,&,', 1),
#              ('A', 5),
#              ('A,', 1),
#              ('A.&', 1),
#              ('Abalone(near)', 1),
#              ('Abalone(resting)', 1),
#              ('Abandoning', 2),
#              ('Accidentally', 1),
#              ('Accidentally&', 1),
#              ("Accidentally's", 1),
#              ('Adrift', 9),
#              ("Adrift'", 1),
#              ("Adrift,,'&", 1),
#              ('After,', 1),
#              ('Air', 4),
#              ('Air,', 1),
#              ('Air.', 1),
#              ('Air/Sea', 2),
#              ('Air/Sea.', 1),
#              ('Air:', 1),
#              ('Aircaft', 1),
#              ('Aircraft', 3),
#              ('Aircraft,', 1),
#              ('American', 3),
#              ('American&', 1),
#              ('American,,&', 1),
#              ('Among(which).', 1),
#              ('Angling', 1),
#              ('Anti(CL,),(Battle)&,,..', 1),
#              ('Anti(Diving)', 1),
#              ('Argentine', 1),
#              ('Arsinoe,', 1),
#              ('Ascending', 1),
#              ('Attaching', 1),
#              ('Attacked', 1),
#              ('Attempted', 1),
#              ('Attempting', 28),
#              ('Attempting&', 1),
#              ("Attempting's", 1),
#              ('B', 1),
#              ('B.', 1),
#              ('Bather', 1),
#              ('Bathing', 220),
#              ('Bathing&', 1),
#              ("Bathing'", 1),
#              ("Bathing''", 1),
#              ('Bathing(bark..,)', 1),
#              ('Bathing,', 1),
#              ('Bathing,.', 1),
#              ('Bathing.', 1),
#              ('Bathing.9', 1),
#              ('Bathing/', 1),
#              ('Bathing/Swimming', 1),
#              ('Batin', 1),
#              ('Beach', 2),
#              ('Being', 1),
#              ('Bending', 1),
#              ('Bitten', 2),
#              ('Board', 1),
#              ('Boarding', 1),
#              ('Boating', 41),
#              ('Boating&', 1),
#              ("Boating'ahu&", 1),
#              ('Boating,', 4),
#              ('Boating,(normally),.', 1),
#              ('Boating,,', 1),
#              ('Boating?', 1),
#              ('Boeing', 1),
#              ('Boogie', 46),
#              ('Boogie,', 1),
#              ('Boogie/', 2),
#              ('Bottom&', 1),
#              ('Bringing,', 1),
#              ('British', 2),
#              ('British&', 1),
#              ('British,,.', 1),
#              ('Burning.S.', 1),
#              ('C47,000', 1),
#              ('Cage', 2),
#              ('Canoe', 3),
#              ('Canoe,', 1),
#              ('Canoe,,', 1),
#              ('Canoeing', 13),
#              ('Capsized', 1),
#              ("Captured'&", 1),
#              ('Cargo', 1),
#              ('Cargo(Aden).', 1),
#              ('Carrying', 1),
#              ('Casting', 1),
#              ('Catching', 4),
#              ('Chasing', 1),
#              ('Checking,', 1),
#              ('Chumming', 2),
#              ('Clamming', 4),
#              ('Cleaning', 5),
#              ('Climbing', 1),
#              ('Clinging', 2),
#              ('Closed(submerged).', 1),
#              ('Collecting', 12),
#              ('Colombian(Avianca)', 1),
#              ('Columbian', 1),
#              ('Coming', 1),
#              ('Commercial', 2),
#              ('Commercial(submerged)', 1),
#              ('Commercial,,&.&.', 1),
#              ('Competing', 4),
#              ('Competing&', 1),
#              ("Competing/W,'", 1),
#              ('Conch', 1),
#              ('Conducting', 1),
#              ('Conducting(a)', 1),
#              ('Copra', 1),
#              ('Crabbing', 3),
#              ('Crabbing(spearing)', 1),
#              ('Crawling', 1),
#              ('Crayfishing', 3),
#              ('Crew', 1),
#              ('Crossing', 3),
#              ('Crossing,,', 1),
#              ('Crouching', 1),
#              ("Crouching'", 1),
#              ('Cruising', 2),
#              ('Cutter', 1),
#              ('Dangling', 5),
#              ("Days,'.", 1),
#              ('Defecating', 1),
#              ('Deserting', 1),
#              ('Disappeared,', 1),
#              ('Dismantling', 1),
#              ('Ditched&.', 1),
#              ('Ditched,.', 1),
#              ('Diving', 330),
#              ('Diving&', 10),
#              ('Diving&/W', 1),
#              ("Diving'", 1),
#              ("Diving's", 1),
#              ("Diving's’s", 1),
#              ('Diving(Helmet)', 1),
#              ('Diving(Hookah)', 1),
#              ('Diving(ascending)', 1),
#              ('Diving(at)', 2),
#              ('Diving(but)', 4),
#              ('Diving(shell)', 1),
#              ('Diving(submerged)', 5),
#              ('Diving,', 15),
#              ("Diving,'", 1),
#              ('Diving,,&', 1),
#              ('Diving.S.', 1),
#              ('Diving.“swallowed’,“shark”', 1),
#              ('Diving/', 5),
#              ('Diving?', 2),
#              ('Dog', 1),
#              ('Dragging', 4),
#              ('Dress', 1),
#              ('Dress,&', 1),
#              ('Drift', 1),
#              ('Dropped', 1),
#              ('Dropping', 1),
#              ('Dry', 1),
#              ('During"an"&', 1),
#              ("During,',", 1),
#              ('Dutch,&&.,,', 1),
#              ('Dynamite', 1),
#              ('Dynamiting', 1),
#              ('Ejected', 1),
#              ('Escaping', 4),
#              ('Esso&', 1),
#              ('Examining,', 1),
#              ('Exercising', 1),
#              ('Explosion&', 1),
#              ("Explosion',", 1),
#              ('Feeding', 10),
#              ('Feeding?', 1),
#              ('Feeling’s', 1),
#              ('Fell', 66),
#              ('Fell&', 4),
#              ('Fell&.,"the."', 1),
#              ('Fell&O', 1),
#              ("Fell'", 1),
#              ("Fell's", 1),
#              ('Fell,', 2),
#              ('Fell?', 1),
#              ('Ferry', 2),
#              ('Ferry&', 1),
#              ('Filming', 2),
#              ('Filming&', 1),
#              ("Filming'", 1),
#              ('Filming,', 1),
#              ('Finning', 3),
#              ('Fisherman', 1),
#              ('Fishing', 535),
#              ('Fishing&', 5),
#              ('Fishing&,', 1),
#              ('Fishing&.', 1),
#              ("Fishing'", 3),
#              ("Fishing'tag&'", 1),
#              ('Fishing(Drowned)', 1),
#              ('Fishing(Seining)', 2),
#              ('Fishing(big)', 1),
#              ('Fishing(illegally)', 1),
#              ('Fishing(rod&)', 1),
#              ('Fishing(trawling)', 1),
#              ('Fishing(trolling)', 2),
#              ('Fishing,', 32),
#              ('Fishing,&', 7),
#              ("Fishing,'", 1),
#              ("Fishing,'&", 1),
#              ("Fishing,'s", 2),
#              ('Fishing,,', 5),
#              ('Fishing,,&', 1),
#              ('Fishing,.', 1),
#              ('Fishing/', 4),
#              ('Fishing/,', 1),
#              ('Fishing?', 1),
#              ('Fishingat', 1),
#              ('Five..5', 2),
#              ('Fleeing', 1),
#              ('Fleet.', 1),
#              ('Fly', 1),
#              ('Flying.', 1),
#              ('Foundering', 1),
#              ('Free', 54),
#              ('Free&', 4),
#              ('Free&(ascending)', 1),
#              ('Free&(descending)', 1),
#              ('Free&(submerged)', 1),
#              ('Free(ascending)', 1),
#              ('Free(but)', 1),
#              ('Free(submerged)', 2),
#              ('Free(surfacing)', 1),
#              ('Free,', 8),
#              ('Free,&', 1),
#              ('Free,/W', 1),
#              ('Free/', 7),
#              ('Free/(resting)', 1),
#              ('Free/,', 2),
#              ('Free/,&', 1),
#              ('Freediving', 11),
#              ('Freediving(at)', 1),
#              ('Freediving(submerged)', 1),
#              ('Freediving,&', 1),
#              ('Gaffing', 1),
#              ('Gaffing&', 1),
#              ('Gathering', 2),
#              ('German', 1),
#              ('Gigging', 1),
#              ('Gloucester', 1),
#              ('Goggle,', 1),
#              ('Grabbed&', 1),
#              ('Grabbing', 1),
#              ('Greek,,', 1),
#              ('H.M.S.&.M.S.Dorsetshire.&', 1),
#              ('HBM', 1),
#              ('HMAS&', 2),
#              ('HMS', 1),
#              ('Had&', 1),
#              ('Hand', 2),
#              ('Harassing', 1),
#              ('Hard', 5),
#              ('Hard,', 1),
#              ('Hardhat', 2),
#              ('Hardhat,', 1),
#              ('Harpooned', 1),
#              ('Harpooning', 1),
#              ('Hauling', 2),
#              ('Hauling,&', 1),
#              ('He', 1),
#              ('He&', 1),
#              ('Helmet', 2),
#              ('Helmet,', 1),
#              ('Helping', 3),
#              ('Hiking', 1),
#              ('Hilo', 1),
#              ('His', 1),
#              ('His,,.&', 1),
#              ('Hoisting', 2),
#              ('Holding', 1),
#              ('Holding&', 1),
#              ("Holding's", 1),
#              ('Hookah', 8),
#              ('Hookah(descending)', 1),
#              ('Hookah(submerged)', 2),
#              ('Hooking', 1),
#              ('Hospital&', 1),
#              ('Human', 1),
#              ('Hunting', 6),
#              ('Hunting.4', 1),
#              ('Hurricane&', 1),
#              ('In', 3),
#              ('In,', 1),
#              ('In.', 1),
#              ('Inebriated,', 1),
#              ('Inflatable', 1),
#              ('Inspecting(hooked&)', 1),
#              ('Investigating', 1),
#              ('Italian', 1),
#              ('Japanese', 1),
#              ('Japanese&', 1),
#              ('Japanese..S.', 1),
#              ('Jerked', 1),
#              ('Jet', 2),
#              ('Jumped', 22),
#              ('Jumped&', 1),
#              ('Jumping', 6),
#              ('Kakaying', 1),
#              ('Kayaking', 51),
#              ('Kayaking(returning)', 1),
#              ('Kayaking/', 5),
#              ('Killing', 2),
#              ('Kite', 16),
#              ('Kiteboarding', 2),
#              ('Kitesurfing', 2),
#              ('Kneeling', 1),
#              ('Knocked', 4),
#              ('Known:,&.', 1),
#              ('Landing', 1),
#              ('Lashing', 1),
#              ('Launching', 3),
#              ('Leaving', 1),
#              ('Leicester', 1),
#              ('LifeBoating', 1),
#              ('Lifesaving', 5),
#              ('Light', 1),
#              ('Line,,,&', 1),
#              ('Lobster', 2),
#              ('Lobstering', 1),
#              ('Longline', 2),
#              ('Longling', 1),
#              ('Loss', 1),
#              ('Lost&', 1),
#              ('Lying', 4),
#              ('Lying&', 1),
#              ("Lying'", 2),
#              ('M.V...', 1),
#              ('Man.&', 1),
#              ('Marathon', 1),
#              ('Measuring', 1),
#              ('Motor', 2),
#              ('Moving', 1),
#              ('Moving,&', 1),
#              ('Murder', 7),
#              ('Murdered', 2),
#              ('NSB', 1),
#              ('National', 1),
#              ('Net', 2),
#              ('Net,', 2),
#              ('Netting', 4),
#              ('Netting,', 1),
#              ('Night', 3),
#              ('No', 1),
#              ('Observing', 1),
#              ('Ocean', 2),
#              ('On', 2),
#              ('On"shark"', 1),
#              ('On&', 2),
#              ("On'", 1),
#              ('On,', 1),
#              ('On,,&.,&', 1),
#              ('On,,,,,,000', 1),
#              ('On.', 1),
#              ("Onboard'", 1),
#              ("Overcome,'&", 1),
#              ('Overturned', 1),
#              ('Oyster', 1),
#              ('Oystering', 1),
#              ('Pacific', 1),
#              ('Painting', 1),
#              ('Parachuted', 2),
#              ('Petting', 2),
#              ('Photo', 1),
#              ('Photographing', 3),
#              ('Picking', 1),
#              ('Placed’s', 1),
#              ('Plane,', 1),
#              ('Plane,.', 1),
#              ('Playing', 20),
#              ('Playing(9)', 1),
#              ('Playing,&', 1),
#              ('Playing/', 2),
#              ('Pleasure', 1),
#              ('Portuguese.', 1),
#              ('Preparing', 1),
#              ('Probabable', 1),
#              ('Pulling', 4),
#              ("Pushed's,'s", 1),
#              ('Put', 1),
#              ('Put&', 1),
#              ('R5D', 1),
#              ('Racing', 1),
#              ('Ran', 1),
#              ('Reached&', 1),
#              ('Reaching', 1),
#              ('Refused,', 1),
#              ('Removing', 7),
#              ('Reported', 1),
#              ('Rescuing', 2),
#              ('Resting', 2),
#              ('Restraining', 1),
#              ('Retrieving', 2),
#              ('Returning,', 1),
#              ('Reviving', 1),
#              ('Riding', 3),
#              ('Rolled', 1),
#              ('Row(from),', 1),
#              ('Rowing', 17),
#              ('Royal&', 1),
#              ('S.S.,,,,', 1),
#              ('S.S..&.', 1),
#              ('S2F', 1),
#              ('S2N,.H.&.G.', 2),
#              ('SCUBA', 4),
#              ('SS', 1),
#              ('SUP', 4),
#              ('Sailboarding,', 1),
#              ('Salvaging', 1),
#              ('Scallop', 1),
#              ('Scallop(using&)', 1),
#              ('Schooner', 1),
#              ("Scientific(Dr.'s)", 1),
#              ('Scooping', 1),
#              ('Sculling', 3),
#              ('Scurfing(surfboard)', 1),
#              ('Sea', 15),
#              ('Sea,', 7),
#              ('Sea,/V', 1),
#              ('Sea:', 1),
#              ('Sea:.', 1),
#              ('Searching.', 1),
#              ('Seine', 4),
#              ('Seining,', 1),
#              ('Setting', 1),
#              ('Shark', 25),
#              ('Shark,', 1),
#              ('Shark.', 1),
#              ('She&', 1),
#              ('Shell', 4),
#              ('Ship&', 2),
#              ("Ship's,&", 1),
#              ('Shipwreck', 6),
#              ('Shipwrecked', 3),
#              ('Shipwrecked;&', 1),
#              ('Shooting', 2),
#              ('Shrimping', 1),
#              ('Sight', 1),
#              ('Sinking', 5),
#              ("Sinking'.", 1),
#              ('Sinking/V', 1),
#              ('Sitting', 19),
#              ("Sitting'", 1),
#              ("Sitting's", 1),
#              ('Sittting', 1),
#              ('Skimboarding', 1),
#              ('Skin', 6),
#              ("Skin.'s;&'s&", 1),
#              ('Skindiving', 8),
#              ('Skindiving(but)', 1),
#              ('Skindiving,', 2),
#              ('Slapped', 1),
#              ('Sleeping', 1),
#              ('Slipped', 1),
#              ('Small,', 1),
#              ('Small.', 2),
#              ('Snorkeling', 90),
#              ('Snorkeling(filming)', 1),
#              ('Snorkeling,', 2),
#              ('Snorkeling–', 1),
#              ('Spear', 1),
#              ('Spear,', 1),
#              ('Speared,’s..', 1),
#              ('Spearfishing', 354),
#              ('Spearfishing&', 6),
#              ('Spearfishing(24).,’s&', 1),
#              ('Spearfishing(Free)', 1),
#              ('Spearfishing(but)', 2),
#              ('Spearfishing(free)', 3),
#              ('Spearfishing,', 17),
#              ('Spearfishing,&', 1),
#              ("Spearfishing,'", 1),
#              ('Spearfishing,,', 2),
#              ('Spearfishing,.&.', 1),
#              ('Spearfishing,’s', 1),
#              ('Spearfishing/', 13),
#              ('Spearfishing/(at)', 3),
#              ('Spearing', 4),
#              ('Spent', 1),
#              ('Splashing', 8),
#              ('Splashing/', 1),
#              ('Sponge', 11),
#              ('Stamding', 1),
#              ('Stand', 6),
#              ('Standing', 115),
#              ("Standing's", 1),
#              ('Standing,', 8),
#              ('Standing/', 7),
#              ('Steamer&,,&', 1),
#              ('Steamer.&.', 1),
#              ('Steinhart', 1),
#              ('Stuffing', 1),
#              ('Suicide', 3),
#              ('Sunbathing', 1),
#              ('Surfing', 1196),
#              ('Surfing"chest"(boogie?)', 1),
#              ('Surfing&', 4),
#              ('Surfing(lying)', 2),
#              ('Surfing(or)', 2),
#              ('Surfing(pneumatic)', 1),
#              ('Surfing(sitting)', 7),
#              ('Surfing(urinating)', 1),
#              ('Surfing,', 17),
#              ('Surfing,&.', 1),
#              ('Surfing,’', 1),
#              ('Surfing/', 6),
#              ('Surfing?', 1),
#              ('Surfingboarding', 1),
#              ('Surfingng', 1),
#              ('Surfingskiing', 5),
#              ('Surfingsurfing', 1),
#              ('Survived', 1),
#              ('Survived,', 1),
#              ('Swept', 3),
#              ('Swept,', 1),
#              ('Swept.S.Frontenac', 1),
#              ('Swimming', 1029),
#              ('Swimming"filibuster"', 1),
#              ('Swimming&', 5),
#              ("Swimming'", 1),
#              ('Swimming(lead)', 1),
#              ('Swimming(recovering)', 1),
#              ('Swimming(using)', 1),
#              ('Swimming,', 17),
#              ('Swimming,&', 2),
#              ('Swimming,.9', 2),
#              ('Swimming.,,,&', 1),
#              ("Swimming.5'’", 1),
#              ('Swimming.E.L.', 1),
#              ('Swimming/', 17),
#              ('Tagging', 4),
#              ('Taken', 1),
#              ('Taking', 1),
#              ('Taking&', 2),
#              ('Tandem', 1),
#              ('Teasing', 2),
#              ('Tech', 1),
#              ('Testing', 2),
#              ('Testing,', 1),
#              ('The', 17),
#              ('The&', 6),
#              ('The&.', 2),
#              ('The&.’s', 1),
#              ('The,,', 2),
#              ('The,,.,.', 1),
#              ('The,516', 1),
#              ('The.', 1),
#              ('The.,,.', 1),
#              ('The/6/1988,', 2),
#              ('Their,000&,', 3),
#              ('Thrashing/"Jaws"', 1),
#              ('Thrown', 4),
#              ('Torpedoed&', 1),
#              ('Touching', 3),
#              ('Towing', 2),
#              ('Trailing', 2),
#              ('Transatlantic', 2),
#              ('Traveling', 1),
#              ('Treading', 35),
#              ('Treading,', 1),
#              ('Treading/', 1),
#              ('Trochus,', 1),
#              ('Trying', 1),
#              ('Tuna,', 1),
#              ('Two.,', 1),
#              ('Tzenny,,', 1),
#              ('U&', 1),
#              ('U.S.', 1),
#              ('U.S..&.', 2),
#              ('USS&/24/1944,.', 1),
#              ('USS/24/1944.&', 1),
#              ('USS/24/1944..', 1),
#              ('Underwater', 1),
#              ('Unknown', 546),
#              ('Unknown,', 1),
#              ('Unknown,"First"', 1),
#              ('Vehicle', 1),
#              ('Vessel&,', 1),
#              ('Vessel,', 1),
#              ('Wade', 10),
#              ('Wading', 155),
#              ('Wading&', 1),
#              ('Wading(shrimping)', 1),
#              ('Wading,', 4),
#              ('Wading,&', 1),
#              ('Wading/', 1),
#              ('Wading/&', 1),
#              ('Wading?', 1),
#              ('Wading’s', 1),
#              ('Wakeboarding', 1),
#              ('Walking', 24),
#              ('Walking,&', 1),
#              ('Walking/', 1),
#              ('Washed', 8),
#              ('Washed&', 1),
#              ('Washing', 13),
#              ('Watching', 2),
#              ('Watching,', 1),
#              ('Water', 1),
#              ('Went', 3),
#              ('When,.', 1),
#              ('Wind', 1),
#              ('Wooden', 1),
#              ('Working', 3),
#              ('Wrangling', 1),
#              ('Wreck', 18),
#              ('Wreck/', 1),
#              ('Yacht', 2),
#              ('Yacht,', 1),
#              ("Zosimo&,,',,&", 1),
#              ("a's", 1),
#              ('canoeing', 1),
#              ('cargo', 1),
#              ('fishing&', 2),
#              ('male', 1),
#              ('native', 1),
#              ('preparing', 1),
#              ('pêcheur', 1),
#              ('seaplane', 1),
#              ('ship&', 1),
#              ('ship.', 1),
#              ('ship.V.', 1),
#              ('small', 1),
#              ('wreck', 1),
#              ('yachting', 1),
#              ('yachtsman', 1)])

# %% [markdown]
# ### Sex

# %%
data.rename(columns={"Sex ":"Sex"}, inplace=True)

# %%
data.Sex = data.Sex.str.rstrip()

# %%
data.Sex= data.Sex.replace(to_replace = 'N', value ='M')

# %%
data.Sex= data.Sex.replace(to_replace = 'lli', value ='Unknown')

# %%
data.Sex= data.Sex.replace(to_replace = '.', value ='Unknown')

# %% [markdown]
# ### Fatal

# %%
data.rename(columns={"Fatal (Y/N)":"Fatal"},inplace=True)

# %%
data.Fatal = data.Fatal.replace(to_replace = 'M', value = 'N' )

# %%
data.Fatal = data.Fatal.replace(to_replace = 'y', value = 'Y' )

# %%
data.Fatal = data.Fatal.replace(to_replace = '2017', value = 'Unknown' )

# %%
data.Fatal = data.Fatal.replace(to_replace = 'UNKNOWN', value = 'Unknown' )

# %% [markdown]
# ### Case Number

# %%
data.rename(columns={"Case Number":"Case_Number"},inplace=True)

# %%
data.Case_Number = data.Case_Number.replace(to_replace = r'(\.\w$)', value = '', regex = True)

# %%
data.Case_Number = data.Case_Number.replace(to_replace = r'\.[A-Z]\w', value = '', regex = True)

# %%
data.Case_Number = data.Case_Number.replace(to_replace = r'\.[A-Z]|[a-z]', value = '', regex = True)

# %%
data.Case_Number = data.Case_Number.replace(to_replace = r'\.$', value = '', regex = True)

# %%
data.Case_Number = data.Case_Number.replace(to_replace = r'\.\ \&', value = '', regex = True)

# %%
data.Case_Number = data.Case_Number.replace(to_replace = r'\/', value = '', regex = True)

# %%
data.Case_Number = data.Case_Number.replace(to_replace = r'(\.|-)\w?$', value = '', regex = True)

# %% [markdown]
# ### Injury

# %% [markdown]
# The information stores in the injury column is too complicated to extract any relevant information that can actually be useful. In another project could be interesting to extract the are of the body that was injures and the type of wound, but it woudl require to create two additional columns and not all cells have relevan information

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Case_Number', 'Year', 'Type', 'Country', 'Area',
#        'Location', 'Activity', 'Sex', 'Age', 'Injury', 'Fatal', 'Time',
#        'Species'],
#       dtype='object')

# %% [markdown]
# ### Species

# %%
list(data.Species.unique())
# Out:
# ['White shark',
#  'Unknown',
#  'shark',
#  'Tiger shark, ',
#  'Tiger shark',
#  'Lemon shark, ',
#  'Bull shark, ',
#  'Grey reef shark',
#  'Invalid incident',
#  'Tawny nurse shark, ',
#  'Shark involvement not confirmed',
#  'Questionable',
#  'White shark,',
#  ' shark',
#  'Juvenile bull shark',
#  'Bull shark',
#  "Tiger shark, '",
#  'Wobbegong shark',
#  'Blacktip shark',
#  'Juvenile white shark,  ',
#  'Bull shark,',
#  'Possibly wobbegong',
#  'Injury believed caused by an eel, not shark',
#  'Galapagos shark?',
#  'Grey reef shark.',
#  'small shark',
#  'Wobbegong shark?',
#  'Juvenile nurse shark',
#  'Nurse shark. ',
#  'Tiger shark, female',
#  'Some drowned but otheray have been killed by blue sharks',
#  'Cookiecutter shark',
#  'Wobbegong shark,',
#  'Spinner shark, feet',
#  'Tiger shark, feet',
#  'Deathay have been due drowning',
#  'Porbeagle,',
#  'White shark, ',
#  'Nurse shark',
#  'Shark involvement questionable',
#  'White shark,  ',
#  'Possibly juvenile blacktip shark',
#  'Oceanic whitetip shark, ',
#  "White shark, '",
#  'Sandtiger shark  ',
#  'Blue shark ',
#  "White shark,  '",
#  'Bull shark,  ',
#  'Tiger shark, kg',
#  'Shark involvement prior death not confirmed',
#  'No shark invovlement ',
#  'Seven-gill shark',
#  ' shark, probably smooth hound',
#  'Shark involvement highly doubtful',
#  'No shark invovlement - it ws publicity stunt',
#  'Lemon shark',
#  'Bull shark, 5',
#  'Lemon shark pup',
#  "White shark, female, '",
#  'Caribbean reef shark',
#  'Wobbegong shark, ',
#  'Broadnose sevengill shark,',
#  '  shark',
#  'Invalid',
#  'Blue shark',
#  'Nurse shark, ',
#  'reef shark, ',
#  'Angel shark',
#  'dogfish shark',
#  'Tawny nurse shark',
#  'Caribbean reef shark, ',
#  'Said involve an  shark bure likely damage caused by debris',
#  'Mako shark',
#  'Bronze whaler sharks x 3',
#  'Blacktip shark, ',
#  'Mako shark, ',
#  'Grey reef shark,',
#  'Tiger shark,',
#  'Nurse shark, ft',
#  'Bronze whaler',
#  'Sandtiger shark',
#  'No shark involvement',
#  'Reef shark, ',
#  'Bull sharks x 2',
#  'Silky shark, ',
#  'Bronze whaler shark, ',
#  'Galapagos shark',
#  'Spinner shark, ',
#  'Hammerhead sp.',
#  'Blacktip shark,  ',
#  'juvenile shark',
#  'Hammerhead shark',
#  'Hammerhead shark.',
#  ' shark?',
#  'Hammerhead shark.  ',
#  'Blacktip or spinner shark, ',
#  'Thought involve  shark, but shark involvement not confirmed',
#  'Mako shark, lb',
#  'Shark involvement not cofirmed',
#  'small nurse shark',
#  ' foot shark',
#  'Blue shark, feet',
#  'Blacktip Reef shark ',
#  'White shark or oceanic whitetip shark',
#  'Raggedoth shark,',
#  'Shark involvement prior death still be determined',
#  'Shark involvement not confirmed & highly unlikely',
#  'Goblin shark',
#  'white shark: & ',
#  'Spinner shark',
#  'Spinner shark or blacktip shark',
#  'reef shark',
#  ' Bull shark, ',
#  "Bull shark,  '",
#  ' tp  shark',
#  'Possibly juvenile tiger shark',
#  'metre shark',
#  ' White shark,  ',
#  "Oceanic whitetip shark'",
#  'Caribbean reef shark,  ',
#  ' Lemon shark,',
#  ' Sandbar shark,  ',
#  ' Bull shark,  ',
#  ' Tawney nurse shark, ',
#  ' white shark, ',
#  'Cow shark',
#  'reef shark?',
#  ' Raggedoth shark, ',
#  'white shark',
#  'Blacktip or spinner shark?',
#  'Blacktip reef shark ',
#  'gill shark?',
#  'gill shark',
#  'Oceanic whitetip shark',
#  'Reported involve bull shark',
#  ' Wobbegong shark, ',
#  'Tiger shark,  ',
#  'Thought involve white shark',
#  'Reported involve white shark',
#  'Blacktip reef shark, ',
#  'Thought involve bull shark',
#  'Whitetip reef shark,  ',
#  'Nurse shark?',
#  'Small bull shark',
#  'Salmon shark',
#  'Tiger shark?',
#  'Possibly Bull shark, ',
#  'Wobbegong, ',
#  'Grey nurse shark, ',
#  'Possibly blacktip reef shark',
#  'shark involvement not confirmed',
#  'small sharks',
#  'Possibly bull shark',
#  'Porbeagle shark, ',
#  'Lemon shark,  ',
#  'White shark or bronze whaler',
#  'Salmon shark suspected, but unlikely',
#  "'shark",
#  'possibly bull shark',
#  'small reef shark',
#  'small blacktip shark?',
#  'Blacktip shark ',
#  'Blue shark, ',
#  'Possibly  bull shark',
#  'Tawny nurse shark, cm',
#  'Grey nurse shark',
#  'Blue shark, -blue shark',
#  'Allegedly tiger shark',
#  ' shark ',
#  'Raggedoth shark',
#  'Port Jackson shark, ',
#  ' shark, possibly blactip or spinner shark',
#  'White shark, >',
#  'Possibly  sandtiger shark',
#  'Grey reef shark ',
#  'Bull shark,  female',
#  'White shark,  k',
#  'Sevengill shark,  ',
#  'Zambesi shark',
#  ' Tiger shark, ',
#  'Sandbar shark, ',
#  "Bull shark, '",
#  'possibly bronze whaler shark',
#  ' Bull shark,',
#  'Blacktip shark pup',
#  'White shark x 2',
#  'Oceanic whitetip shark,  ',
#  'Mako shark ',
#  'Oceanic whitetip shark, , female',
#  'Porbeagle shark,  ',
#  'Possibly  lemon shark',
#  'Shark involvement prior death was not confirmed',
#  'Possibly small blacktip shark',
#  'Sandtiger shark,  ',
#  'small spinner shark',
#  'Nurse shark, juvenile ',
#  'Possibly blue shark',
#  'Thought involve juvenile hammerhead shark',
#  'Whitetip reef shark, ',
#  'Zambesi shark,  ',
#  'Sandtiger shark, ',
#  'Thresher shark',
#  'Spurdog',
#  'White shark,  juvenile ',
#  'Bull shark?',
#  'Thought involve Bronze whale shark, ',
#  'Shark involvement probable, but not confirmed',
#  'blacktip or spinner shark',
#  'White shark, female',
#  'Bronze whaler shark?',
#  'Blacktip reef shark pup',
#  'Thought involve cookie cutter shark',
#  'Wobbegong shark, cm',
#  'White sharks',
#  'Dusky shark, ',
#  'Broadnose sevengill shark',
#  'Raggedoth shark, ',
#  'Zambesi shark?',
#  'Bronze whaler shark',
#  ' reef shark, ',
#  '+ shark',
#  ' juvenile shark',
#  ' bull shark or Caribbean reef shark',
#  ' white shark or gill shark',
#  ' reef shark',
#  'Starry smoothhound shark, ',
#  'Basking shark',
#  'Tiger sharks in area',
#  'small bull sharks',
#  'Reported byedias shark attack, but shark involvement prior death was not confirmed',
#  'Shark involvement not confirmed; thought be barracudbite',
#  'bull shark, according some of the divers on the boat',
#  'Goblin shark, ',
#  'Mako shark, kg',
#  "Nurse shark, '",
#  'Possibly hammerhead shark',
#  'Not shark attack; it was hoax',
#  'Oceanic whitetip sharks were in the vicinity',
#  'Gray reef shark',
#  'Nurse shark,  ',
#  'Possibly spinner shark',
#  'Sand shark',
#  ' ',
#  ' small spotted catshark, Scyliorhinus canicula',
#  'Questionable Incident',
#  'Lemon shark,  female ',
#  '-year-old -pound pregnant blacktip reef shark',
#  'Lesser spotted dogfish, Scyliorhinus canicula, less than  cin length',
#  ' shark, possibly tiger shark',
#  'Raggedoth shark, kg',
#  'small catsharks',
#  'White shark?',
#  'Thought involve aako shark, but possibly selion',
#  'Angel shark,  ',
#  'Shark involvement not confirmed, injuryay have been caused by bluefish',
#  'Bull or tiger shark',
#  ' spinner or bull shark',
#  'blacktip reef shark',
#  'Possibly  blacktip or spinner shark',
#  "Tiger shark,  '",
#  'Grey reef shark,  ',
#  'Bull shark,  bull shark',
#  'Bronze whaler shark,  juvenile ',
#  'm, shark',
#  'Bronze whaler shark,',
#  'Said involve shark',
#  'Whitetip reef shark',
#  'Raggedoth shark,  ',
#  "Tiger shark, less than '",
#  'Caribbean reef sharks',
#  'shark, shark T',
#  'juvenile white shark',
#  'Possibly sandbar shark or small blacktip shark',
#  '',
#  'bull shark',
#  'On / anglers froNew Zealand caught , [lb] shark at the same spot. It was believed this was the same shark that killed Alysha',
#  'Unknown, but it was reported that shark oth was recovered frothe wound',
#  'Mr. Burgess of ISAF announced the injury was the bite of ,  year old white shark. Subsequent investigation revealed there was  no shark involvement in this incident',
#  'copper shark',
#  'blacktip shark',
#  'small hammerhead shark',
#  'Bronze whaler shark,   ',
#  '& white shark ',
#  ' white shark',
#  'Thought involve bull or tiger shark',
#  '  white shark',
#  'Longfinako shark, , [lb] ',
#  'sharks, & ',
#  'black tipped shark',
#  'Caribbean reef shark (Carcharhinus  perezi)',
#  'Wobbegong shark, k',
#  'sevengill  shark',
#  ' c blind or brown shark',
#  'Possibily  sandtiger shark',
#  'Shark involvement doubtful',
#  'Bull shark,  was speared & killed',
#  'Bull shark, [lb] ',
#  'Mako shark,  ',
#  'Shortfinako shark',
#  'Tiger shark,  ?',
#  'oceanic whitetip shark',
#  'Nurse shark,  cc ',
#  'shark, either bronze whaler or grey nurse shark',
#  'grey-colored shark',
#  'cow shark',
#  'Unidentified species',
#  ' bull shark',
#  ' great hammerhead shark',
#  'c shark',
#  '“small brown shark”',
#  'sand shark',
#  'reef shark - or  grey-colored shark',
#  '“small” shark',
#  ' cc bite diameter just below left knee',
#  ' ccaptive shark',
#  'Species unidentified',
#  'Thought involve grey nurse shark',
#  'Thought involve  bull shark',
#  'Reported involve hammerhead shark',
#  'White shark, white shark',
#  'Shark involvement not confirmed, injuryay be due stingray',
#  ' grey colored shark',
#  '\xa0 Caribbean Reef Shark ',
#  'Possibly bull shark or tiger shark',
#  'Blacktip or spinner shark',
#  'Tiger shark, k',
#  ' hammerhead or bonnethed shark',
#  'blacktip or sandbar shark',
#  'Mako shark, lb ',
#  ' shark, possibly bull shark',
#  'Tiger shark,   ',
#  ' shark; Tooth fragment recovered frohand',
#  '\xa0 ',
#  ' copper shark',
#  ' blacktip shark',
#  'Bull shark, lb ',
#  'Spinner shark,  ',
#  'Shark involvement prior death unconfired',
#  'whaler shark',
#  'C. leucas oth fragment recovered frokayak',
#  'Unidentified',
#  'Questionable incident - shark biteay have precipitated drowning',
#  'sandtiger shark',
#  'large white shark was filmed by divers on local wreck days prior the incident.',
#  ' shark, possibly  blacktip or spinner shark',
#  'Possibly juvenile blacktip or spinner shark',
#  'Possibly blacktip or spinner shark',
#  'shark, possibly whitetip reef shark',
#  'Bronze whaler shark,  k',
#  ' black finned shark',
#  'Porbeagle shark, rk',
#  '[lb] dead blue shark',
#  ' cc shark',
#  'White shark,  ale ',
#  'Thought involve Zambesi shark',
#  ' shark was seen in the areby witnesses',
#  'Thought involve , lb bull shark',
#  'Shark involvement  not confirmed',
#  'Grey reef shark, ',
#  'Lemon shark,   ',
#  'shark,  probably blacktip or spinner shark',
#  'Tiger sharks & bull sharks ( sharks in all)',
#  'Tiger shark, ?',
#  'Shark involvement  questionable',
#  'Shortfinako shark,  ',
#  'Miami,  cblacktip  shark and two  cbamboo catsharks',
#  'Sevengill shark',
#  'Thought involve white, bull or tiger shark',
#  'Said involve white shark',
#  'bull sharks',
#  'Sevengill shark, ',
#  'Mako shark, gaffed ',
#  ' shark seen in the vicinity',
#  'Bronze whaler or tiger shark',
#  'Possibly white shark',
#  'White shark,   ',
#  'Though involve white shark',
#  'Sandtiger shark,,ale ',
#  'Thought involve white shark named Kong',
#  'Lemon shark, , identified  by the surfer',
#  'shark, possibly blacktip',
#  ' spinner shark',
#  'Small dusky shark or blackfin shark',
#  'Shark involvement prior death suspected but not confirmed',
#  'Possibly blacktip shark',
#  'Soupfin shark',
#  'small blacktip shark',
#  'Thought involve an oceanic whitetip shark or white shark',
#  'shark (spinner shark?)',
#  'Possibly sand shark',
#  'Possibly Caribbean reef shark',
#  'young shark',
#  ' hammerhead shark',
#  'said involve an oceanic whitetip shark',
#  'white shark ',
#  ' cc blacktip or spinner shark',
#  'nurse shark',
#  'Possibly tiger shark',
#  'Tiger shark, [lb] ',
#  '   shark',
#  'Two  sharks',
#  'White shark (oth fragment recovered)',
#  'Though involve tiger shark',
#  'Leopard shark',
#  'Thought involve small sand shark',
#  'Small shark',
#  'spinner shark',
#  ', [lb] bull shark',
#  'Tiger shark said be  ',
#  'On -Jan-, his remains washed ashore. tiger shark thought be involved',
#  'Tiger shark caught days later with diver’s remains in its gut',
#  'blacktip shark or Caribbean reef shark',
#  ' white shark, according witnesses',
#  ' shark, oth fragments recovered ',
#  'Thought involve tiger shark',
#  'Remains recovered frowhite shark',
#  'Possiby white shark',
#  'Tiger shark, , (oth fragment recovered frowound)',
#  'Two oceanic whitetip sharks',
#  'hammerhead shark',
#  'Unidentified shark',
#  '  white shark ',
#  'Questionable incident',
#  'Nurse shark, ,  ',
#  'Bull shark or lemon shark',
#  'White shark, identification by K. Nakaya',
#  ', white shark',
#  ' white shark, identification by K. Nakaya',
#  'Said involve  white shark',
#  'grey shark',
#  'Zambesi shark, ',
#  ',  [lb] shark',
#  ', lb reef shark',
#  'bull or lemon shark',
#  ' female white shark named Notchfin',
#  'kg, shark',
#  ' female shark',
#  'Shark had very large girth',
#  'Grey nurse shark,',
#  'shark ',
#  'Shark involvement prior death could not be determined',
#  'hammerhead',
#  'white shark, identified by witnesses & otharks',
#  'white shark, identified by M. Smale',
#  "Two sharks seen in vicinity: &   [ & '] TL",
#  'shark, possibly bronze whaler',
#  'Shark involvement suspected but not confirmed',
#  'White shark, identified by oth pattern',
#  'lb shark',
#  'Sandbar shark',
#  'Blue Shark ',
#  'gaffed shark',
#  ' silvertip shark',
#  'Sand shark?',
#  'Zambezi shark (oth fragments recovered)',
#  'Mako shark, , [lb] ',
#  ' sharks attacked survivors in the water',
#  'Doubtful / Unconfirmed attack / Unable verify in local records',
#  ' spinner or blacktip shark',
#  'Raggedoth shark, , ',
#  'Lemon shark, , oth fragment recovered',
#  'Tooth fragment of white shark recovered. Authorities believed shark was  tal length',
#  'dusky shark',
#  ' sixgill or sevengill shark',
#  'Thought involve Tiger shark,  ',
#  ', lb shark',
#  'silky shark',
#  'Possibly small hammerhead shark',
#  '-shark',
#  'white shark, oth fragments recovered',
#  'Shark involvement not confirmed; officials considered barracua',
#  'Hammerhead shark?+O',
#  'small blue shark',
#  'Raggedoth shark ',
#  'Raggedoth shark, -[lb] ',
#  ' dusky shark',
#  'white-tipped reef shark',
#  '.shark',
#  'Raggedoth shark, (oth fragment recovered)',
#  'Zambezi shark',
#  'Blue sharks',
#  'Believed involve white shark',
#  'Questionable incident; reported as shark attack but thought involve pinniped instead ',
#  'shark, possibly spinner shark',
#  'white shark, species identity confirmed by oth fragment',
#  'Reported as shark attack, the sry was hoax',
#  'white shark, species identity confirmed by witnesses & oth pattern in surfboard',
#  "[''] white shark",
#  ', hooked & shot white shark',
#  'shark with very flat head” that had followed the boat for days',
#  'Said involve tiger shark or hammerhead shark',
#  'shark, species identity questionable',
#  'Shark involvement prior death remains unconfirmed',
#  'Mako shark (oth fragments recovered)',
#  'sandshark',
#  'Possibly  Zambezi shark',
#  'gray shark',
#  "', lb thresher shark",
#  ' bull, sandbar or dusky shark',
#  'C.aculpinnis or C. limbatus',
#  'Juvenile dusky or blacktip shark',
#  'dogfish',
#  'Said involve white shark but shark involvement not confirmed',
#  'Raggedoth shark, -[lb], gaffed ',
#  'White shark, , oth fragment recovered',
#  'Sevengill shark,',
#  'Thought involve blacktip shark',
#  'white shark (Tooth  recovered froboat)',
#  'Bull shark, 8',
#  'Mako shark,,  ',
#  'White shark, k',
#  'lemon shark or bull shark',
#  'White shark, , species identity confirmed by oth fragment',
#  'Blue shark,  ',
#  'Mako shark, [lb]',
#  'Whale shark',
#  'White shark named “Spotty”',
#  'Juvenile dusky shark',
#  'Shark involvement unconfirmed',
#  'Carpet shark, ',
#  'Copper shark, - ',
#  ' blue shark',
#  'Shortfinako shark, ',
#  "White shark, [.'] ",
#  "small sharks'",
#  'sharks',
#  'Bronze whaler shark,  ',
#  '  blacktip shark',
#  'shark, possibly dusky or blacktip shark',
#  ' shark observed in area',
#  'White shark, > ',
#  'Oceanic whitetip shark x 2',
#  'White shark, [. .] ',
#  'grey reef shark',
#  'White shark, rk',
#  "Grey nurse shark, '",
#  'White shark, , species identity confirmed by witnesses & oth pattern in leg & board ',
#  ' porbeagle shark',
#  'White shark according oth pattern and witnesses',
#  'C. albimarginatus',
#  'Dog shark',
#  'Raggedoth shark, , year-old, captive female ',
#  'Wobbegong shark ',
#  'Carpet shark',
#  'Considered Doubtful incident',
#  'White shark, identified by oth fragments in surfboard',
#  'scalloped hammerhead sharks, & [ & ]',
#  '-blackfin shark',
#  'White shark, , (oth fragment recovered)',
#  'Not authenticated',
#  ' Caribbean reef shark ',
#  'Blue whaler (Galeolamna)',
#  'Nurse shark, cm, ,ale ',
#  ' sandbar shark',
#  'White shark or thresher shark',
#  'Bronze whaler shark, , oth was embedded in the speargun ',
#  'pack of sharks',
#  'Spinner or blacktip sharks',
#  'Lemon shark or sandtiger shark',
#  'Local authorities speculated that the water was o cold for sharks, but , lb pregnant sandbar shark was caught next day',
#  'Believed white shark and other smaller species of sharks involved.',
#  'Alleged involve White shark, ',
#  'White shark, , an immature female, previously injured',
#  'Copper shark',
#  'Wobbegong shark,  ',
#  ' Zambesi shark',
#  ' ccarpet shark',
#  'carpet shark',
#  'sharks involved',
#  '[lb] shark',
#  'Lemon shark,',
#  'Tiger shark, oth fragment recovered',
#  ', [lb] shark ',
#  'whaler',
#  'Nurse shark,   ',
#  'Small shark with white-tipped dorsal fin',
#  ' shark, possibly aako shark',
#  'White shark, , lb ',
#  'Less than ',
#  'Lemon shark ',
#  'Tiger shark,, lb female',
#  'Wobbegong',
#  ',  shark',
#  ' lb Zambesi shark',
#  'Possibly broadnose gill shark',
#  ' tiger shark',
#  'Dooley believed his Injury was caused by stingray (Dasyatidae family)',
#  "Hand found in gut of [ '] Galapagos shark, C. galapagensis",
#  ' shark seen in vicinity',
#  'Tooth fragments of “whaler” shark were recovered, bull shark, according Edwards',
#  '<shark',
#  "White shark, ', lb ",
#  'White shark, (or bronze whaler)',
#  ', .[lb]  shark',
#  'blue whaler',
#  ' Blacktip shark, C.aculipinnis.  ',
#  'long thin brown-colored shark',
#  'Horn shar,k Heterodontus francisci, ',
#  ' sharks',
#  'Possibly bronze whaler shark',
#  ' Sevengill  shark, ',
#  ' c shark ',
#  'Said involve red shark',
#  ' Grey nurse shark,  ',
#  'Bronze whaler shark, shark',
#  'Said involve Grey nurse shark ',
#  'Nexrning shark was caught that had Andrewsleg in its gut',
#  "Two shark's teeth recovered frocanoe",
#  'Oceanic whitetip shar,; identified by Dr. W.C. Schoeder on phograph & Dr. L.P. L. Schultz on sketch by observer',
#  'White shark, ,  ',
#  'Hammerhead shark, llb ',
#  ' yellow belly captive shark. Shark destroyed by aquariustaff next day',
#  'Wobbegong shark, O. barbatus,  , identified by G.P. Whitley',
#  ' gummy shark (Rhizoprionodon or Loxodon) ',
#  'Grey nurse shark, , lb ',
#  'Bronze whaler shark, Identified by Clyde Buttery',
#  'Grey reef shark, grey reef shark, identified by Dr. L.P. L. Schultz based on phographs; identified as C.elanopterus by Stewart',
#  ' banjo shark',
#  ', -shark',
#  'White shark, based on bite pattern',
#  'Hammerhead shark, ',
#  'Six Zambesi sharks seen in length',
#  '> shark',
#  'White shark, , oth fragment frowounds identified as that of white shark',
#  'Grey nurse shark,  ',
#  'White shark (oth fragments recovered frohull of boat)',
#  'White shark, oth fragment  recovered frothe hull',
#  'Lemon shark, m, immatureale, identified by  V.G. Springer',
#  ' hooked shark',
#  'Mako shark,   with hook & wire leader caught inouth',
#  'Dusky shark, dusky shark C. obscurus identified by S. Springer on oth recovered',
#  'Lemon shark, ale, N. breviostris, identified by W.A. Stark II, later the same day  pregnant female lemon shark bit the bow of the boat',
#  'White shark,  based on oth pattern',
#  'Bronze whaler shark, , lb',
#  'Raggedoth shark, lb ',
#  'Bronze whaler shark, identified by G.P. Whitley based on description',
#  'White shark (oth fragments recovered)',
#  ', possibly  larger shark',
#  'Two sharks',
#  'According Benjamin, the injury was inflicted by barracuda, not shark',
#  'Tiger shark, captured',
#  'Shark involvement prior deaths was not confirmed',
#  'shark captured',
#  'Blue pointer',
#  'Blacktail reef shark',
#  'Blacktip reef shark',
#  'tiger shark',
#  'Thresher shark, ',
#  'White shark, , identified by Dr. W. I. Follett on otharks',
#  'hammerhead shark, then other sharks were said be  involved',
#  'Said involve white shark, but species identify questionable',
#  'White shark, , identified by W. I.  Follett on oth fragments',
#  'White shark, based on teeth retrieved frorudder',
#  'Hammerhead shark,  ',
#  'Hammerhead shark, S. zygenidentified by C. Limbaugh on description',
#  'Blue shark?',
#  'Nurse shark,  c, identified by Dr. L.P. L. Schultz on phograph',
#  'Oceanic whitetip shark,',
#  'Reported involve White shark,  ',
#  'White shark, ; identifed by Dr. W.I. Follett on otharks',
#  'Tiger shark ',
#  'Mako shark, , <lb, identified by Dr. L.P. L. Schultz on phograph',
#  'Bitten by several sharks',
#  'Said involve sharks: &  ',
#  'White shark,   according Shreuder and witness',
#  'Sharks averaged in length',
#  'Nurse shark,  identified by Dr. E. Clark on description of shark',
#  'Tiger shark, <TL',
#  'Nurse shark,  identified by Dr. E. Clark on color & oth impressions',
#  'Mako shark, [lb] ',
#  'Several sharks involved',
#  'Identified as carcharinid shark (based on its behavior) by Dr. D.P. L. Schultz;ako shark according Huges',
#  'bull shark, identified by Capt. W. Gray',
#  'Said involve  white shark, but thought  that it wasore likely blue shark',
#  'Shark seen feeding on turtle scraps thrown overboard prior incident.',
#  'Said involve largeako shark',
#  'tiger shark caught  hours later with shorts of the boy in its gut',
#  'White shark, according witnesses',
#  "White shark, ',  female ",
#  'Porbeagle or white shark',
#  'shark &ay have been another shark nearby',
#  ' sand shark',
#  'Survivors said species of sharks were involved:  oceanic whitetip sharks and another species',
#  'Survivors said species of sharks were involved:  oceanic whitetip sharks and another species,',
#  ' thresher or blue shark. The shark  was killed following the incident',
#  'Tooth fragments recovered frohull',
#  'small brown-colored shark',
#  'Leopard shark,  Triakis semifasciata, identified by J.W. DeWitt ()',
#  'White shark, [. ] ',
#  ' white shark  (or bronze whaler)',
#  'shark x 6',
#  'little shark',
#  'shark, possibly dusky shark',
#  'White shark oth fragment recovered froankle & identified by Dr. W. I. Follett',
#  'Bull shark suspected due freshwater habitat',
#  "small shark'",
#  'Said involve  shark',
#  'shark seen in vicinity',
#  'White shark, , [lb], identified by W. C. Shroeder based on oth fragment ebedded in gunwale',
#  'shark, probable bull shark',
#  'Carpet shark,  ',
#  ' (m) brown shark',
#  'small slibrown shark',
#  'Bull shark, was captured & dragged on the sand where tissue taken froEggink was found in its gut. Species identification  wasade by S. Springer based on phographs of the shark. ',
#  'Attacked by number of sharks',
#  'White shark, , seen in areand hooked days later',
#  'unknown, possibly white shark',
#  ' “spear-eye” shark ',
#  'small carpet shark',
#  'White shark,  according witnesses',
#  'White shark,,  kgale',
#  'Possibly lemon shark',
#  'Whtietip reef shark',
#  'Alleged involve white shark with little yellow eyes',
#  'shark with black-tipped pecral fins',
#  'Bonitsharkk, lb',
#  'Whaler shark, ,  lb  identified by G.P. Whitley',
#  'His hand was found in tiger shark caught ',
#  'Said be shark',
#  'Possibly C. leucas',
#  'Most likely, small shark',
#  'm, -shark',
#  'Tiger shark, ,   ',
#  'blacktip shark or spinner shark',
#  'Bull sharks  in length',
#  'Shark involvement prior death unconfirmed',
#  "White shark,  (Tooth fragment recovered frovictim's shoulder & identified by J.T. Nicholls)",
#  'White shark,, kg,ale',
#  ' sharks,ost were oceanic whitetip sharks',
#  'White shark,   according witnesses',
#  'Tiger shark & others',
#  'Porbeagle shark',
#  'Said be “leopard sharks”,ore probably tiger sharks',
#  'Reportedly: oceanic whitetip sharks, blue sharks, tiger sharks & bull sharks',
#  'Mako shark (akbonishark) ',
#  'White shark, species identity confirmed by oth pattern',
#  'White shark, [lb], identity confirmed by oth pattern',
#  ' White shark',
#  'Questionable incident, said involve  shark',
#  'shark landed hours later',
#  "Blue pointer, '",
#  'Tiger shark, , oth fragments retrieved frohis wounds',
#  'large shark',
#  'Thought involve bull sharks',
#  "Tiger shark,  , female, contained Girvan's remains ",
#  'Whaler shark, ',
#  'days later lb shark was caught yards frothe site',
#  ' blue nosed shark',
#  'Large tiger shark seen in the vicinity the followingorning',
#  'Shovelnose shark, ',
#  'White shark (identified by Dr. Hugh Smith) ',
#  'Blue shark,  , lb ',
#  'Tiger shark  ',
#  'Blue nose shark',
#  'Blue pointer, ',
#  ' blue-nosed shark',
#  'Mako shark, identified by oth fragments by G.P. Whitley',
#  ' tiger shark &  shark',
#  'shark seen in areprevious week',
#  'Thought involve lemon shark; two lemon sharks caught within yds of the site week prior & week after this incident',
#  'Thought involve aako or grey nurse shark',
#  'Teeth in hull identified as those frowhite shark in length',
#  'lb dog shark',
#  'Hammerhead shark, , according lifeguard SaBarrows',
#  'school of sharks',
#  'cocktail shark',
#  "shark's teeth found embedded in the woodwork of the boat",
#  'White shark ',
#  'White shark, , identity confirmed by witness & oth pattern',
#  'foot shark',
#  'dog shark',
#  'Blue nose sharks',
#  'Moreno’s leg  & part of his swisuit found in  shark caught two hours after the attack. Identified as carcharhinid shark by L. Schultz & C. Limbaugh on phograph',
#  'Species unknown, possibly white shark',
#  'White shark,  . ',
#  'Grey nurse shark?',
#  'whiptail shark (thresher shark?)',
#  'white shark or sevengill shark',
#  'Questionable,  shark suspected',
#  "According Carlsmith, the shark'south was  wide",
#  'blue shark',
#  'Said be “small shark”',
#  'Mako shark, . Tooth fragment recovered & identified by J.T. Nichols.',
#  'very large shark',
#  'Atkinsremains were recovered frodusky shark, C. obscurus, by Capt. W. F. Young, shark fisherman',
#  "White shark, ', identity confirmed by oth fragment, witness and phograph of captured shark ",
#  'shark later captured by Mitchell-Hedges',
#  "Comrades saw shark's tail appear about  away",
#  '*  dog shark',
#  "'",
#  ',  shark. Shark caught & its jaw exhibited at the Carnegie Museum',
#  'Tiger sharks,  ',
#  'Reported involve shark, possibly white shark',
#  'shark known as Old Tom',
#  'said involve tiger shark',
#  'Said involve hammerhead shark',
#  'whaler shark captured days later with his remains in its gut',
#  'C.acrurus captured  hours after attack with tissue removed froman in its gut; species identified by G.P. Whitley,  reported as C. obscurus by  R. Steel',
#  'Said involve   blue shark',
#  '-foot shark',
#  'Remains recovered frosharks',
#  'Species unknown, possible white shark',
#  'Allegedly -foot shark',
#  'Shark involvement probable',
#  'Shortfinako shark, lb ',
#  'Remains recovered days later',
#  'Fishermen recovered partial remains froshark week later',
#  "' shark",
#  "Sevengill shark, ', was caught in the vicinity",
#  ',  female shark',
#  'Unknown, but the shark was caught and put on exhibition',
#  'Shark was said “have very rough ½”-thick skin”',
#  'Said involve sharks',
#  ' small shark',
#  'Blue or porbeagle shark',
#  'Wobbegongs',
#  'Identified as C. gangeticus by Dr. J. Fayrer',
#  'Shark caught later',
#  ' ground shark',
#  'Remains recovered froshark caught days later',
#  'Shark involvement prior deaths unconfirmed',
#  'Tiger shark (pregnant)',
#  'Thought involve porbeagle orako shark',
#  'Description of shark does not ring true',
#  'The fish was harpooned, dried, and presented the sailor, who went round Europe exhibiting it  It was said be  feet long.',
#  'White shark,  female ',
#  'Possibly white sharks',
#  ' Galapagos shark, ',
#  'said involve hammerhead sharks',
#  'Silvertip shark',
#  'large hammerhead shark',
#  'Shovelnose guitarfish, adultale ',
#  'White shark, lb ',
#  "Bull shark caught, leg recovered & buried beside thean's body",
#  'black-tipped shark',
#  'Blue pointers',
#  'Said involve grey nurse shark that leapt out of the water and  seized the boy but species identification is questionable']

# %%
data.Species = data.Species.replace(to_replace = r'"', value = '', regex = True)

# %%
data.Species = data.Species.replace(to_replace = r'\d.', value='', regex=True)

# %%
data.Species = data.Species.replace(to_replace = r'\ m', value='', regex=True)

# %%
data.Species = data.Species.replace(to_replace = r'to\s*', value='', regex=True)

# %%
data.Species = data.Species.replace(to_replace = r"\['] |\[] |A |a |m |kg |-lb|\[' ']|\['  ']|\[ ']|\[']|\[. ']|\[.]|\[]|\' ' |\\' |\' |>m|", value='', regex=True)

# %%
data.=mentions.message.str.extract('(@[a-zA-Z0-9_.-]*)',expand=False)
